# %%
import pandas as pd

# %%
matchSummary = pd.read_csv('dataset/match_summary.csv')
matchBattingSummary = pd.read_csv('dataset/match_batting_summary.csv')
matchBowlingSummary = pd.read_csv('dataset/match_bowling_summary.csv')
players = pd.read_csv('dataset/players.csv')

# %%
matchSummary
# Out:
#           Team 1        Team 2        Winner      Margin     Ground  \
# 0        England      Pakistan       England   5 wickets  Melbourne
# 1        England         India       England  10 wickets   Adelaide
# 2    New Zealand      Pakistan      Pakistan   7 wickets     Sydney
# 3          India      Zimbabwe         India     71 runs  Melbourne
# 4     Bangladesh      Pakistan      Pakistan   5 wickets   Adelaide
# 5    Netherlands  South Africa   Netherlands     13 runs   Adelaide
# 6        England     Sri Lanka       England   4 wickets     Sydney
# 7      Australia   Afghanistan     Australia      4 runs   Adelaide
# 8        Ireland   New Zealand   New Zealand     35 runs   Adelaide
# 9       Pakistan  South Africa      Pakistan     33 runs     Sydney
# 10    Bangladesh         India         India      5 runs   Adelaide
# 11   Netherlands      Zimbabwe   Netherlands   5 wickets   Adelaide
# 12       England   New Zealand       England     20 runs   Brisbane
# ...

# %%
matchSummary.shape
# Out:
# (42, 7)

# %%
matchSummary.rename({'Scorecard': 'Match Id'}, axis = 1, inplace = True)

# %%
match_ids_dict = {}
for index, row in matchSummary.iterrows():
    key1 = row['Team 1'] + ' Vs ' + row['Team 2']
    key2 = row['Team 2'] + ' Vs ' + row['Team 1']
    match_ids_dict[key1] = row['Match Id']
    match_ids_dict[key2] = row['Match Id']

# %%
matchBattingSummary
# Out:
#                     match teamInnings  battingPos           batsmanName  runs  \
# 0     England vs Pakistan    Pakistan           1      Mohammad Rizwan     15
# 1     England vs Pakistan    Pakistan           2            Babar Azam    32
# 2     England vs Pakistan    Pakistan           3       Mohammad Haris      8
# 3     England vs Pakistan    Pakistan           4          Shan Masood     38
# 4     England vs Pakistan    Pakistan           5       Iftikhar Ahmed      0
# ..                    ...         ...         ...                   ...   ...
# 694  Namibia vs Sri Lanka   Sri Lanka           7    Wanindu Hasaranga      4
# 695  Namibia vs Sri Lanka   Sri Lanka           8  Chamika Karunaratne      5
# 696  Namibia vs Sri Lanka   Sri Lanka           9      Pramod Madushan      0
# 697  Namibia vs Sri Lanka   Sri Lanka          10  Dushmantha Chameera      8
# 698  Namibia vs Sri Lanka   Sri Lanka          11   Maheesh Theekshana     11
#
# ...

# %%
matchBattingSummary['batsmanName'] = matchBattingSummary['batsmanName'].apply(lambda x: x.replace('â€', ''))
matchBattingSummary['batsmanName'] = matchBattingSummary['batsmanName'].apply(lambda x: x.replace('\xa0', ''))
matchBattingSummary.head()
# Out:
#                  match teamInnings  battingPos       batsmanName  runs  balls  \
# 0  England vs Pakistan    Pakistan           1  Mohammad Rizwan     15     14
# 1  England vs Pakistan    Pakistan           2        Babar Azam    32     28
# 2  England vs Pakistan    Pakistan           3   Mohammad Haris      8     12
# 3  England vs Pakistan    Pakistan           4      Shan Masood     38     28
# 4  England vs Pakistan    Pakistan           5   Iftikhar Ahmed      0      6
#
#    4s  6s      SR out/not_out match_id
# 0   0   1  107.14         out      NaN
# 1   2   0  114.28         out      NaN
# 2   1   0   66.66         out      NaN
# 3   2   1  135.71         out      NaN
# 4   0   0    0.00         out      NaN

# %%
matchBowlingSummary
# Out:
#                     match bowlingTeam       bowlerName  overs  maiden  runs  \
# 0     England vs Pakistan     England       Ben Stokes    4.0       0    32
# 1     England vs Pakistan     England     Chris Woakes    3.0       0    26
# 2     England vs Pakistan     England       Sam Curran    4.0       0    12
# 3     England vs Pakistan     England      Adil Rashid    4.0       1    22
# 4     England vs Pakistan     England     Chris Jordan    4.0       0    27
# ..                    ...         ...              ...    ...     ...   ...
# 495  Namibia vs Sri Lanka     Namibia      David Wiese    4.0       0    16
# 496  Namibia vs Sri Lanka     Namibia  Bernard Scholtz    4.0       0    18
# 497  Namibia vs Sri Lanka     Namibia     Ben Shikongo    3.0       1    22
# 498  Namibia vs Sri Lanka     Namibia          JJ Smit    3.0       0    16
# 499  Namibia vs Sri Lanka     Namibia     Jan Frylinck    4.0       0    26
#
# ...

# %%
players
# Out:
#                name          team  \
# 0     Glenn Maxwell     Australia
# 1     James Neesham   New Zealand
# 2     Anrich Nortje  South Africa
# 3         Yasir Ali    Bangladesh
# 4      Akeal Hosein   West Indies
# ..              ...           ...
# 208    Bas de Leede   Netherlands
# 209    Rohit Sharma         India
# 210  Curtis Campher       Ireland
# 211   Tony Munyonga      Zimbabwe
# 212         JJ Smit       Namibia
#
#                                                  image    battingStyle  \
# 0    https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# 1    https://img1.hscicdn.com/image/upload/f_auto,t...   Left hand Bat
# 2    https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# 3    https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# 4    https://img1.hscicdn.com/image/upload/f_auto,t...   Left hand Bat
# ..                                                 ...             ...
# ...

# %%
players['name'] = players['name'].apply(lambda x: x.replace('â€', ''))
players['name'] = players['name'].apply(lambda x: x.replace('†', ''))
players['name'] = players['name'].apply(lambda x: x.replace('\xa0', ''))
players.head(10)
# Out:
#              name          team  \
# 0   Glenn Maxwell     Australia
# 1   James Neesham   New Zealand
# 2   Anrich Nortje  South Africa
# 3       Yasir Ali    Bangladesh
# 4    Akeal Hosein   West Indies
# 5  Iftikhar Ahmed      Pakistan
# 6     Zahoor Khan        U.A.E.
# 7      Tom Cooper   Netherlands
# 8     Josh Little       Ireland
# 9     Odean Smith   West Indies
#
#                                                image    battingStyle  \
# 0  https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# 1  https://img1.hscicdn.com/image/upload/f_auto,t...   Left hand Bat
# 2  https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# 3  https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# 4  https://img1.hscicdn.com/image/upload/f_auto,t...   Left hand Bat
# 5  https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# 6  https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# ...
